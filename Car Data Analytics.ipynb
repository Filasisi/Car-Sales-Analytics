# %%
# The inline flag will use the appropriate backend to make figures appear inline in the notebook.  
# %matplotlib inline

import pandas as pd
import numpy as np

# `plt` is an alias for the `matplotlib.pyplot` module
import matplotlib.pyplot as plt

# import seaborn library (wrapper of matplotlib)
import seaborn as sns

# %% [markdown]
# ## Load Data - Car Pricing

# %%
# load car pricing data file
filename = 'carpricing.csv'
df = pd.read_csv(filename)

# %%
df
# Out:
#      car_ID  symboling                   CarName fueltype aspiration  \
# 0         1          3        alfa-romero giulia      gas        std
# 1         2          3       alfa-romero stelvio      gas        std
# 2         3          1  alfa-romero Quadrifoglio      gas        std
# 3         4          2               audi 100 ls      gas        std
# 4         5          2                audi 100ls      gas        std
# ..      ...        ...                       ...      ...        ...
# 200     201         -1           volvo 145e (sw)      gas        std
# 201     202         -1               volvo 144ea      gas      turbo
# 202     203         -1               volvo 244dl      gas        std
# 203     204         -1                 volvo 246   diesel      turbo
# 204     205         -1               volvo 264gl      gas      turbo
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# ...

# %%
# Select top N number of records(default = 5)
df.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# ...

# %%
# Select bottom N number of records(default = 5)
df.tail()
# Out:
#      car_ID  symboling          CarName fueltype aspiration doornumber  \
# 200     201         -1  volvo 145e (sw)      gas        std       four
# 201     202         -1      volvo 144ea      gas      turbo       four
# 202     203         -1      volvo 244dl      gas        std       four
# 203     204         -1        volvo 246   diesel      turbo       four
# 204     205         -1      volvo 264gl      gas      turbo       four
#
#     carbody drivewheel enginelocation  wheelbase  ...  enginesize  fuelsystem  \
# 200   sedan        rwd          front      109.1  ...         141        mpfi
# 201   sedan        rwd          front      109.1  ...         141        mpfi
# 202   sedan        rwd          front      109.1  ...         173        mpfi
# 203   sedan        rwd          front      109.1  ...         145         idi
# 204   sedan        rwd          front      109.1  ...         141        mpfi
#
# ...

# %%
# Check the column data types using the dtypes attribute
df.dtypes
# Out:
# car_ID                int64
# symboling             int64
# CarName              object
# fueltype             object
# aspiration           object
# doornumber           object
# carbody              object
# drivewheel           object
# enginelocation       object
# wheelbase           float64
# carlength           float64
# carwidth            float64
# carheight           float64
# curbweight            int64
# enginetype           object
# cylindernumber       object
# enginesize            int64
# fuelsystem           object
# boreratio           float64
# stroke              float64
# compressionratio    float64
# horsepower            int64
# peakrpm               int64
# citympg               int64
# highwaympg            int64
# price               float64
# dtype: object

# %%
# Use the shape attribute to get the number of rows and columns in your dataframe
df.shape
# Out:
# (205, 26)

# %%
# The info method gives the column datatypes + number of non-null values 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
# ...

# %% [markdown]
# ## Grouping the data into Categorical and Numerical Data

# %%
def check_data_type(df):
       
    categorical_list = []
    numerical_list = []
    
    #Looping through each of the columns 
    for col in df.columns.tolist():
        if df[col].dtype=='object':
            categorical_list.append(col)
        else:
            numerical_list.append(col)
    
    #make dataframe that have two feature, that is categorical and numerical feature
    categorical = pd.Series(categorical_list, name='Categorical Feature')
    numerical = pd.Series(numerical_list, name='Numerical Feature')
    df_dtypes = pd.concat([categorical,numerical], axis=1)
    
    return df_dtypes

# %%
check_data_type(df)
# Out:
#    Categorical Feature Numerical Feature
# 0              CarName            car_ID
# 1             fueltype         symboling
# 2           aspiration         wheelbase
# 3           doornumber         carlength
# 4              carbody          carwidth
# 5           drivewheel         carheight
# 6       enginelocation        curbweight
# 7           enginetype        enginesize
# 8       cylindernumber         boreratio
# 9           fuelsystem            stroke
# 10                 NaN  compressionratio
# 11                 NaN        horsepower
# 12                 NaN           peakrpm
# 13                 NaN           citympg
# 14                 NaN        highwaympg
# 15                 NaN             price

# %% [markdown]
# ## Checking Unique Catergories Per Column for Categorical Data

# %%
def unique_entry(df):
    '''
    Parameter 
    ---------
    df : array
        the data frame that will be checked the unique the entities 
    '''
    for col in df.columns:
        if df[col].dtypes == 'object':
            unique_cat = len(df[col].unique())
            print("Feature '{col}' has {unique_cat} unique categories".format(col=col, unique_cat=unique_cat))

# %%
unique_entry(df)
# Out:
# Feature 'CarName' has 28 unique categories
# Feature 'fueltype' has 2 unique categories
# Feature 'aspiration' has 2 unique categories
# Feature 'doornumber' has 2 unique categories
# Feature 'carbody' has 5 unique categories
# Feature 'drivewheel' has 3 unique categories
# Feature 'enginelocation' has 2 unique categories
# Feature 'enginetype' has 7 unique categories
# Feature 'cylindernumber' has 7 unique categories
# Feature 'fuelsystem' has 8 unique categories

# %%
df.describe()
# Out:
#            car_ID   symboling   wheelbase   carlength    carwidth   carheight  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000  205.000000
# mean   103.000000    0.834146   98.756585  174.049268   65.907805   53.724878
# std     59.322565    1.245307    6.021776   12.337289    2.145204    2.443522
# min      1.000000   -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%     52.000000    0.000000   94.500000  166.300000   64.100000   52.000000
# 50%    103.000000    1.000000   97.000000  173.200000   65.500000   54.100000
# 75%    154.000000    2.000000  102.400000  183.100000   66.900000   55.500000
# max    205.000000    3.000000  120.900000  208.100000   72.300000   59.800000
#
#         curbweight  enginesize   boreratio      stroke  compressionratio  \
# count   205.000000  205.000000  205.000000  205.000000        205.000000
# mean   2555.565854  126.907317    3.329756    3.255415         10.142537
# ...

# %% [markdown]
# ## Get car Manufacturer from "CarName" column

# %%
df['CarName'] = df['CarName'].apply(lambda x: x.split(' ')[0])

# %%
df.head()
# Out:
#    car_ID  symboling      CarName fueltype aspiration doornumber      carbody  \
# 0       1          3  alfa-romero      gas        std        two  convertible
# 1       2          3  alfa-romero      gas        std        two  convertible
# 2       3          1  alfa-romero      gas        std        two    hatchback
# 3       4          2         audi      gas        std       four        sedan
# 4       5          2         audi      gas        std       four        sedan
#
#   drivewheel enginelocation  wheelbase  ...  enginesize  fuelsystem  \
# 0        rwd          front       88.6  ...         130        mpfi
# 1        rwd          front       88.6  ...         130        mpfi
# 2        rwd          front       94.5  ...         152        mpfi
# 3        fwd          front       99.8  ...         109        mpfi
# 4        4wd          front       99.4  ...         136        mpfi
#
#    boreratio  stroke compressionratio horsepower  peakrpm citympg  highwaympg  \
# ...

# %% [markdown]
# ### Rename CarName to Manufacturer

# %%
df = df.rename(columns={'CarName': 'manufacturer'})

# %%
df.head()
# Out:
#    car_ID  symboling manufacturer fueltype aspiration doornumber      carbody  \
# 0       1          3  alfa-romero      gas        std        two  convertible
# 1       2          3  alfa-romero      gas        std        two  convertible
# 2       3          1  alfa-romero      gas        std        two    hatchback
# 3       4          2         audi      gas        std       four        sedan
# 4       5          2         audi      gas        std       four        sedan
#
#   drivewheel enginelocation  wheelbase  ...  enginesize  fuelsystem  \
# 0        rwd          front       88.6  ...         130        mpfi
# 1        rwd          front       88.6  ...         130        mpfi
# 2        rwd          front       94.5  ...         152        mpfi
# 3        fwd          front       99.8  ...         109        mpfi
# 4        4wd          front       99.4  ...         136        mpfi
#
#    boreratio  stroke compressionratio horsepower  peakrpm citympg  highwaympg  \
# ...

# %%
df['manufacturer'].unique()
# Out:
# array(['alfa-romero', 'audi', 'bmw', 'chevrolet', 'dodge', 'honda',
#        'isuzu', 'jaguar', 'maxda', 'mazda', 'buick', 'mercury',
#        'mitsubishi', 'Nissan', 'nissan', 'peugeot', 'plymouth', 'porsche',
#        'porcshce', 'renault', 'saab', 'subaru', 'toyota', 'toyouta',
#        'vokswagen', 'volkswagen', 'vw', 'volvo'], dtype=object)

# %% [markdown]
# ### Replace Manufacturer's name that are wrongly spelt

# %%
#This code is used to correct spelling mistakes for manufacturers name 

def replace_name(a,b):
    df['manufacturer'].replace(a,b,inplace=True)

replace_name('maxda','mazda')
replace_name('Nissan','nissan')
replace_name('toyouta','toyota')
replace_name('porcshce','porsche')
replace_name('vokswagen','volkswagen')
replace_name('vw','volkswagen')

# %%
# check to ensure all spoking mistakes have been corrected
df['manufacturer'].unique()
# Out:
# array(['alfa-romero', 'audi', 'bmw', 'chevrolet', 'dodge', 'honda',
#        'isuzu', 'jaguar', 'mazda', 'buick', 'mercury', 'mitsubishi',
#        'nissan', 'peugeot', 'plymouth', 'porsche', 'renault', 'saab',
#        'subaru', 'toyota', 'volkswagen', 'volvo'], dtype=object)

# %% [markdown]
# ### Check for duplicate rows

# %%
sum(df.duplicated(subset = 'car_ID')) == 0
# No duplicate values
# Out:
# True

# %% [markdown]
# ### Check for null Values

# %% [markdown]
# #The output below shows that there is not Null value in any cell in the data.
# df.isnull().sum()*100/df.shape[0]

# %% [markdown]
# ## Frequency of Car Sold

# %%
plt.figure(figsize=(30, 8))
plt1=sns.countplot(x=df.manufacturer, data=df, order= df.manufacturer.value_counts().index)
plt.title('Number of Car Sold by Manufacturer', size=25)
plt1.set_xlabel('Manufacturer', fontsize=19)
plt1.set_ylabel('Number of Car Sold', fontsize=19)
plt1.set_xticklabels(plt1.get_xticklabels(),rotation=360, size=14)
plt.show()

# %% [markdown]
# ##### The Chart of Frequency of Car Sold shows that more Toyota's were sold than any other car manufacturer while Mercury should the least.

# %% [markdown]
# ## Boxplot for Price and Manufacturing

# %%
def box_plot(data, x_column, y_column = "price"):
    sns.boxplot(x = x_column, y = y_column, data = df)
    plt.title(str(x_column).title() + " and " + str(y_column).title(), fontsize = 22)
    plt.xlabel(x_column.title(), fontsize = 15)
    plt.ylabel(y_column.title(), fontsize = 15)

# %%
plt.figure(figsize = (10, 10))
box_plot(df, x_column = "price", y_column = "manufacturer")

# %% [markdown]
# ##### The boxplot shows that BMW, Jaguar, Buick and Porshe seem to be more pricy that the other cars sold by Oxmoor Car Dealership in 2020. Also, it shows that the most expensive car that was sold by OCD was maunfactured by Buick.

# %% [markdown]
# ## Fuel Type
#
# All cars sold by Oxmoor Car Dealership in 2020 either were either powered by Gas or Diesel. Ploting both to see which fuel type was more prefered by the customer.

# %%
sns.countplot(x = "fueltype", data = df)
plt.title("Gas vs Diesel", fontsize = 20)
plt.ylabel("Count")
plt.xlabel("Fuel Type")
# Out:
# Text(0.5, 0, 'Fuel Type')

# %% [markdown]
# ##### The Gas vs Diesel Customers generelly prefer  gas fuelled cars

# %%
box_plot(df, "fueltype")
plt.title("Fuel Type vs Price", fontsize = 20)
# Out:
# Text(0.5, 1.0, 'Fuel Type vs Price')

# %% [markdown]
# ##### "Fuel Type vs Price" shows that diesel fuelled cars are generally more expensive with few gas fuelled cars being more expensive that diesel cars. Gas powered car with higher prices than the diesel cars were outliers.

# %%
sns.countplot(x = "aspiration", data = df)
plt.title("Aspiration Type: Std vs Turbo", fontsize = 20)
plt.ylabel("Count")
plt.xlabel("Fuel Type")
# Out:
# Text(0.5, 0, 'Fuel Type')

# %%
sns.boxplot(x = "aspiration", y = "price", hue = "fueltype", data = df)
plt.title("Aspiration, Price by Fuel Type")
plt.ylabel("Price")
plt.xlabel("Aspiration")
# Out:
# Text(0.5, 0, 'Aspiration')
